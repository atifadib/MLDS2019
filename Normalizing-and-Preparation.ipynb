# %%
#Imports
#====================
import pandas as pd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#====================

data = pd.read_csv('final_train_data.csv')

data.head()
# Out:
#    Unnamed: 0 Country Name Country Code  Year       Balance  Inflation  \
# 0           0      Senegal          SEN  1983 -3.043829e+08   9.274213
# 1           1         Togo          TGO  2009 -1.766692e+08   1.855275
# 2           2     Pakistan          PAK  1992 -1.876092e+09  10.057085
# 3           3        Nepal          NPL  1988 -2.714506e+08  11.815310
# 4           5        Malta          MLT  2016  7.269132e+08   1.604548
#
#         GDP       Exports      Trade
# 0 -5.326393  6.180000e+08  59.224298
# 1  3.510297  9.030260e+08  76.242542
# 2  7.705898  7.351000e+09  34.489440
# 3  7.696809  1.900000e+08  24.978422
# 4  5.516617  3.017299e+09  83.781471

# %% [markdown]
# #### Filling in NaN Values

# %%
year_to_features_given_country = dict()
for idx,row in data.iterrows():
    row.to_dict()
    try:
        year_to_features_given_country[row['Country Code']].append(row)
    except KeyError:
        year_to_features_given_country[row['Country Code']] = [row]
for country, data_list in year_to_features_given_country.items():
    temp = dict()
    for _ in data_list:
        temp[_['Year']] = [_['Inflation'],_['GDP'],_['Exports'],_['Trade']]
    year_to_features_given_country[country] = temp

# %%
train_data = []
for idx,row in data.iterrows():
    row.to_dict()
    line = []
    line.append(row['Country Code'])
    line.append(row['Balance'])
    line.append(row['Year'])
    for idx,feature in enumerate(['Inflation','GDP','Exports','Trade']):
        if np.isnan(row[feature]):
            min_year = min(year_to_features_given_country[row['Country Code']].keys())
            curr_year = row['Year']
            s=False
            for c in range(curr_year,min_year,-1):
                try:
                    imputed_feature = year_to_features_given_country[row['Country Code']][c][idx]
                    if not np.isnan(imputed_feature):
                        line.append(imputed_feature)
                        print('imputed',imputed_feature,'for',feature,'in the year',curr_year)
                        s=True
                        break
                except KeyError:
                    continue
            if s==False:
                line.append("Remove")
        else:
            line.append(row[feature])
    if "Remove" not in line:
        train_data.append(line)
# Out:
# imputed 14.27570645 for Inflation in the year 2014
# imputed -6.881302064 for GDP in the year 2014
# imputed 429.3684626 for Trade in the year 2014
# imputed 2.962802421 for Inflation in the year 2016
# imputed 6.000194324 for GDP in the year 2016
# imputed 58.70044877 for Trade in the year 2016
# imputed 14.27570645 for Inflation in the year 2011
# imputed -6.881302064 for GDP in the year 2011
# imputed 4933844549.0 for Exports in the year 2016
# imputed 107.4659439 for Trade in the year 2016
# imputed 4933844549.0 for Exports in the year 2015
# imputed 107.4659439 for Trade in the year 2015
# imputed 14.27570645 for Inflation in the year 2012
# imputed -6.881302064 for GDP in the year 2012
# imputed 429.3684626 for Trade in the year 2012
# imputed 2.965962733 for Inflation in the year 1991
# imputed -10.0496666 for GDP in the year 1991
# imputed 18.25071664 for Inflation in the year 2015
# imputed -62.07591958 for GDP in the year 2015
# imputed 77.79973568 for Trade in the year 2015
# imputed 14.27570645 for Inflation in the year 2015
# imputed -6.881302064 for GDP in the year 2015
# imputed 429.3684626 for Trade in the year 2015
# imputed 40.44049011 for Inflation in the year 2015
# imputed -3.894386475 for GDP in the year 2015
# imputed 24.43883541 for Trade in the year 2015
# imputed 14.27570645 for Inflation in the year 2013
# imputed -6.881302064 for GDP in the year 2013
# imputed 429.3684626 for Trade in the year 2013
# imputed -18.43514848 for Inflation in the year 2016
# imputed 5.652702701 for GDP in the year 2016
# imputed 31.74902951 for Trade in the year 1992
# imputed 40.44049011 for Inflation in the year 2016
# imputed -3.894386475 for GDP in the year 2016
# imputed 24.43883541 for Trade in the year 2016
# imputed 14.27570645 for Inflation in the year 2016
# imputed -6.881302064 for GDP in the year 2016
# imputed 429.3684626 for Trade in the year 2016
# imputed 18.25071664 for Inflation in the year 2012
# imputed -62.07591958 for GDP in the year 2012
# imputed 77.79973568 for Trade in the year 2012
# imputed 31.74902951 for Trade in the year 1991
# imputed 2.965962733 for Inflation in the year 1990
# imputed -10.0496666 for GDP in the year 1990
# imputed 14.27570645 for Inflation in the year 2010
# imputed -6.881302064 for GDP in the year 2010
# imputed 7.789747358 for Inflation in the year 2010
# imputed 4.999999998 for GDP in the year 2010
# imputed 67.22393569 for Trade in the year 2010
# imputed 18.25071664 for Inflation in the year 2016
# imputed -62.07591958 for GDP in the year 2016
# imputed 77.79973568 for Trade in the year 2016
# imputed 7.789747358 for Inflation in the year 2009
# imputed 4.999999998 for GDP in the year 2009
# imputed 67.22393569 for Trade in the year 2009
# imputed 7.789747358 for Inflation in the year 2008
# imputed 4.999999998 for GDP in the year 2008
# imputed 67.22393569 for Trade in the year 2008

# %%
train_data = pd.DataFrame(train_data,columns=['Country Code','Balance','Year','Inflation','GDP','Exports','Trade'])
train_data.head()
# Out:
#   Country Code       Balance  Year  Inflation       GDP       Exports  \
# 0          SEN -3.043829e+08  1983   9.274213 -5.326393  6.180000e+08
# 1          TGO -1.766692e+08  2009   1.855275  3.510297  9.030260e+08
# 2          PAK -1.876092e+09  1992  10.057085  7.705898  7.351000e+09
# 3          NPL -2.714506e+08  1988  11.815310  7.696809  1.900000e+08
# 4          MLT  7.269132e+08  2016   1.604548  5.516617  3.017299e+09
#
#        Trade
# 0  59.224298
# 1  76.242542
# 2  34.489440
# 3  24.978422
# 4  83.781471

# %%
print("Checking for NaN values in Dataset")
print(train_data.isnull().any())
print("Original Size:",len(data))
print("New Size:",len(train_data))
# Out:
# Checking for NaN values in Dataset
# Country Code    False
# Balance         False
# Year            False
# Inflation       False
# GDP             False
# Exports         False
# Trade           False
# dtype: bool
# Original Size: 4506
# New Size: 4240

# %%
column_to_min_max = dict()
for column in train_data.columns[2:]:
    print(column)
    print("Max:",max(train_data[column]))
    print("Min:",min(train_data[column]))
    column_to_min_max[column]={'min':min(train_data[column]),'max':max(train_data[column])}
    print('===================================')
# Out:
# Year
# Max: 2016
# Min: 1961
# ===================================
# Inflation
# Max: 12338.66161
# Min: -29.69106658
# ===================================
# GDP
# Max: 34.49999951
# Min: -62.07591958
# ===================================
# Exports
# Max: 2340000000000.0
# Min: 2000000.0
# ===================================
# Trade
# Max: 957.7840112
# Min: 7.920909083
# ===================================

# %%
def min_max_normalize(value,column):
    return (value-column_to_min_max[column]['max'])/(column_to_min_max[column]['max']-column_to_min_max[column]['min'])
train_data['norm_year'] = train_data['Year'].apply(lambda x:min_max_normalize(x,'Year'))
train_data['norm_gdp'] = train_data['GDP'].apply(lambda x:min_max_normalize(x,'GDP'))
train_data['norm_trade'] = train_data['Trade'].apply(lambda x:min_max_normalize(x,'Trade'))
train_data['norm_inflation'] = train_data['Inflation'].apply(lambda x:min_max_normalize(x,'Inflation'))
train_data['norm_exports'] = train_data['Exports'].apply(lambda x:min_max_normalize(x,'Exports'))

# %%
df = train_data[['Balance','norm_year','norm_gdp','norm_trade','norm_inflation','norm_exports']]
rs = np.random.RandomState(0)
corr = df.corr()
corr.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_61d1d8b6_24a1_11e9_acae_f2002062a201row0_col0 {
#             background-color:  #023858;
#         }    #T_61d1d8b6_24a1_11e9_acae_f2002062a201row0_col1 {
#             background-color:  #f7f0f7;
#         }    #T_61d1d8b6_24a1_11e9_acae_f2002062a201row0_col2 {
#             background-color:  #f3edf5;
#         }    #T_61d1d8b6_24a1_11e9_acae_f2002062a201row0_col3 {
#             background-color:  #f0eaf4;
#         }    #T_61d1d8b6_24a1_11e9_acae_f2002062a201row0_col4 {
#             background-color:  #f5eff6;
#         }    #T_61d1d8b6_24a1_11e9_acae_f2002062a201row0_col5 {
#             background-color:  #fdf5fa;
#         }    #T_61d1d8b6_24a1_11e9_acae_f2002062a201row1_col0 {
#             background-color:  #fbf4f9;
#         }    #T_61d1d8b6_24a1_11e9_acae_f2002062a201row1_col1 {
#             background-color:  #023858;
#         }    #T_61d1d8b6_24a1_11e9_acae_f2002062a201row1_col2 {
#             background-color:  #fbf3f9;
#         }    #T_61d1d8b6_24a1_11e9_acae_f2002062a201row1_col3 {
#             background-color:  #efe9f3;
#         }    #T_61d1d8b6_24a1_11e9_acae_f2002062a201row1_col4 {
#             background-color:  #fdf5fa;
#         }    #T_61d1d8b6_24a1_11e9_acae_f2002062a201row1_col5 {
#             background-color:  #d4d4e8;
#         }    #T_61d1d8b6_24a1_11e9_acae_f2002062a201row2_col0 {
#             background-color:  #faf3f9;
#         }    #T_61d1d8b6_24a1_11e9_acae_f2002062a201row2_col1 {
#             background-color:  #fdf5fa;
#         }    #T_61d1d8b6_24a1_11e9_acae_f2002062a201row2_col2 {
#             background-color:  #023858;
#         }    #T_61d1d8b6_24a1_11e9_acae_f2002062a201row2_col3 {
#             background-color:  #f0eaf4;
#         }    #T_61d1d8b6_24a1_11e9_acae_f2002062a201row2_col4 {
#             background-color:  #fff7fb;
#         }    #T_61d1d8b6_24a1_11e9_acae_f2002062a201row2_col5 {
#             background-color:  #fff7fb;
#         }    #T_61d1d8b6_24a1_11e9_acae_f2002062a201row3_col0 {
#             background-color:  #f2ecf5;
#         }    #T_61d1d8b6_24a1_11e9_acae_f2002062a201row3_col1 {
#             background-color:  #ede7f2;
#         }    #T_61d1d8b6_24a1_11e9_acae_f2002062a201row3_col2 {
#             background-color:  #ece7f2;
#         }    #T_61d1d8b6_24a1_11e9_acae_f2002062a201row3_col3 {
#             background-color:  #023858;
#         }    #T_61d1d8b6_24a1_11e9_acae_f2002062a201row3_col4 {
#             background-color:  #f9f2f8;
#         }    #T_61d1d8b6_24a1_11e9_acae_f2002062a201row3_col5 {
#             background-color:  #fff7fb;
#         }    #T_61d1d8b6_24a1_11e9_acae_f2002062a201row4_col0 {
#             background-color:  #fdf5fa;
#         }    #T_61d1d8b6_24a1_11e9_acae_f2002062a201row4_col1 {
#             background-color:  #fff7fb;
#         }    #T_61d1d8b6_24a1_11e9_acae_f2002062a201row4_col2 {
#             background-color:  #fff7fb;
#         }    #T_61d1d8b6_24a1_11e9_acae_f2002062a201row4_col3 {
#             background-color:  #fef6fb;
#         }    #T_61d1d8b6_24a1_11e9_acae_f2002062a201row4_col4 {
#             background-color:  #023858;
#         }    #T_61d1d8b6_24a1_11e9_acae_f2002062a201row4_col5 {
#             background-color:  #fef6fa;
#         }    #T_61d1d8b6_24a1_11e9_acae_f2002062a201row5_col0 {
#             background-color:  #fff7fb;
#         }    #T_61d1d8b6_24a1_11e9_acae_f2002062a201row5_col1 {
#             background-color:  #d2d3e7;
#         }    #T_61d1d8b6_24a1_11e9_acae_f2002062a201row5_col2 {
#             background-color:  #faf3f9;
#         }    #T_61d1d8b6_24a1_11e9_acae_f2002062a201row5_col3 {
#             background-color:  #fff7fb;
#         }    #T_61d1d8b6_24a1_11e9_acae_f2002062a201row5_col4 {
#             background-color:  #f9f2f8;
#         }    #T_61d1d8b6_24a1_11e9_acae_f2002062a201row5_col5 {
#             background-color:  #023858;
#         }</style>
# <table id="T_61d1d8b6_24a1_11e9_acae_f2002062a201" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Balance</th>
#         <th class="col_heading level0 col1" >norm_year</th>
#         <th class="col_heading level0 col2" >norm_gdp</th>
#         <th class="col_heading level0 col3" >norm_trade</th>
#         <th class="col_heading level0 col4" >norm_inflation</th>
#         <th class="col_heading level0 col5" >norm_exports</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_61d1d8b6_24a1_11e9_acae_f2002062a201level0_row0" class="row_heading level0 row0" >Balance</th>
#         <td id="T_61d1d8b6_24a1_11e9_acae_f2002062a201row0_col0" class="data row0 col0" >1</td>
#         <td id="T_61d1d8b6_24a1_11e9_acae_f2002062a201row0_col1" class="data row0 col1" >0.0123001</td>
#         <td id="T_61d1d8b6_24a1_11e9_acae_f2002062a201row0_col2" class="data row0 col2" >0.0186439</td>
#         <td id="T_61d1d8b6_24a1_11e9_acae_f2002062a201row0_col3" class="data row0 col3" >0.0744837</td>
#         <td id="T_61d1d8b6_24a1_11e9_acae_f2002062a201row0_col4" class="data row0 col4" >0.00119983</td>
#         <td id="T_61d1d8b6_24a1_11e9_acae_f2002062a201row0_col5" class="data row0 col5" >-0.0145227</td>
#     </tr>    <tr>
#         <th id="T_61d1d8b6_24a1_11e9_acae_f2002062a201level0_row1" class="row_heading level0 row1" >norm_year</th>
#         <td id="T_61d1d8b6_24a1_11e9_acae_f2002062a201row1_col0" class="data row1 col0" >0.0123001</td>
#         <td id="T_61d1d8b6_24a1_11e9_acae_f2002062a201row1_col1" class="data row1 col1" >1</td>
#         <td id="T_61d1d8b6_24a1_11e9_acae_f2002062a201row1_col2" class="data row1 col2" >-0.0328948</td>
#         <td id="T_61d1d8b6_24a1_11e9_acae_f2002062a201row1_col3" class="data row1 col3" >0.0790919</td>
#         <td id="T_61d1d8b6_24a1_11e9_acae_f2002062a201row1_col4" class="data row1 col4" >-0.0478494</td>
#         <td id="T_61d1d8b6_24a1_11e9_acae_f2002062a201row1_col5" class="data row1 col5" >0.205763</td>
#     </tr>    <tr>
#         <th id="T_61d1d8b6_24a1_11e9_acae_f2002062a201level0_row2" class="row_heading level0 row2" >norm_gdp</th>
#         <td id="T_61d1d8b6_24a1_11e9_acae_f2002062a201row2_col0" class="data row2 col0" >0.0186439</td>
#         <td id="T_61d1d8b6_24a1_11e9_acae_f2002062a201row2_col1" class="data row2 col1" >-0.0328948</td>
#         <td id="T_61d1d8b6_24a1_11e9_acae_f2002062a201row2_col2" class="data row2 col2" >1</td>
#         <td id="T_61d1d8b6_24a1_11e9_acae_f2002062a201row2_col3" class="data row2 col3" >0.0700877</td>
#         <td id="T_61d1d8b6_24a1_11e9_acae_f2002062a201row2_col4" class="data row2 col4" >-0.0660294</td>
#         <td id="T_61d1d8b6_24a1_11e9_acae_f2002062a201row2_col5" class="data row2 col5" >-0.0295597</td>
#     </tr>    <tr>
#         <th id="T_61d1d8b6_24a1_11e9_acae_f2002062a201level0_row3" class="row_heading level0 row3" >norm_trade</th>
#         <td id="T_61d1d8b6_24a1_11e9_acae_f2002062a201row3_col0" class="data row3 col0" >0.0744837</td>
#         <td id="T_61d1d8b6_24a1_11e9_acae_f2002062a201row3_col1" class="data row3 col1" >0.0790919</td>
#         <td id="T_61d1d8b6_24a1_11e9_acae_f2002062a201row3_col2" class="data row3 col2" >0.0700877</td>
#         <td id="T_61d1d8b6_24a1_11e9_acae_f2002062a201row3_col3" class="data row3 col3" >1</td>
#         <td id="T_61d1d8b6_24a1_11e9_acae_f2002062a201row3_col4" class="data row3 col4" >-0.0242342</td>
#         <td id="T_61d1d8b6_24a1_11e9_acae_f2002062a201row3_col5" class="data row3 col5" >-0.0322988</td>
#     </tr>    <tr>
#         <th id="T_61d1d8b6_24a1_11e9_acae_f2002062a201level0_row4" class="row_heading level0 row4" >norm_inflation</th>
#         <td id="T_61d1d8b6_24a1_11e9_acae_f2002062a201row4_col0" class="data row4 col0" >0.00119983</td>
#         <td id="T_61d1d8b6_24a1_11e9_acae_f2002062a201row4_col1" class="data row4 col1" >-0.0478494</td>
#         <td id="T_61d1d8b6_24a1_11e9_acae_f2002062a201row4_col2" class="data row4 col2" >-0.0660294</td>
#         <td id="T_61d1d8b6_24a1_11e9_acae_f2002062a201row4_col3" class="data row4 col3" >-0.0242342</td>
#         <td id="T_61d1d8b6_24a1_11e9_acae_f2002062a201row4_col4" class="data row4 col4" >1</td>
#         <td id="T_61d1d

# %%
df_normed = train_data[['Country Code','Balance','norm_year','norm_gdp','norm_trade','norm_inflation','norm_exports']]

# %%
df_normed.head()
# Out:
#   Country Code       Balance  norm_year  norm_gdp  norm_trade  norm_inflation  \
# 0          SEN -3.043829e+08  -0.600000 -0.412384   -0.945989       -0.996850
# 1          TGO -1.766692e+08  -0.127273 -0.320884   -0.928072       -0.997449
# 2          PAK -1.876092e+09  -0.436364 -0.277441   -0.972029       -0.996786
# 3          NPL -2.714506e+08  -0.509091 -0.277535   -0.982042       -0.996644
# 4          MLT  7.269132e+08   0.000000 -0.300110   -0.920135       -0.997470
#
#    norm_exports
# 0     -0.999737
# 1     -0.999615
# 2     -0.996859
# 3     -0.999920
# 4     -0.998711

# %%
df_normed.to_excel("normed_train_data.xlsx")

# %%
import pickle
with open("feature_normalization_dict.pickle",'wb') as f:
    pickle.dump(column_to_min_max,f)
